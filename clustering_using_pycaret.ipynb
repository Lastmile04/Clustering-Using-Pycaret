# %% [markdown]
# ---
# # **PyCaret for Clustering**
# ---
# - It is a bundle of many Machine Learning algorithms.
# - Only three lines of code is required to compare 20 ML models.
# - Pycaret is available for:
#     - Classification
#     - Regression
#     - Clustering
#
# ---
#
# ### **Self learning resource**
# 1. Tutorial on Pycaret **<a href="https://pycaret.readthedocs.io/en/latest/tutorials.html"> Click Here</a>**
#
# 2. Documentation on Pycaret-Clustering: **<a href="https://pycaret.readthedocs.io/en/latest/api/clustering.html"> Click Here </a>**
#
# ---

# %% [markdown]
# ### **(a) Install Pycaret**

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %% [markdown]
# ### **(b) Get the version of the pycaret**

# %%
from pycaret.utils import version
version()
# Out:
# '3.3.0'

# %% [markdown]
# ---
# # **1. Clustering - Part 1 (Kmean Clustering)**
# ---
# ### **1.1 Get the list of datasets available in pycaret (55)**

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection              None              None
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit              None
# 4       Classification (Binary)             Class              None
# 5       Classification (Binary)             Class              None
# 6       Classification (Binary)           default              None
# 7       Classification (Binary)    Class variable              None
# 8       Classification (Binary)             stabf              None
# 9       Classification (Binary)              left              None
# 10      Classification (Binary)             DEATH              None
# 11      Classification (Binary)           Disease              None
# 12      Classification (Binary)             Class              None
# 13      Classification (Binary)       income >50K              None
# 14      Classification (Binary)          Purchase              None
# 15      Classification (Binary)       TARGET_5Yrs              None
# 16      Classification (Binary)              type              None
# 17      Classification (Binary)             Class              None
# 18      Classification (Binary)          Survived              None
# 19      Classification (Binary)      party_winner              None
# 20  Classification (Multiclass)              Type              None
# 21  Classification (Multiclass)           species              None
# 22  Classification (Multiclass)             CLASS              None
# 23  Classification (Multiclass)     Next_Question              None
# 24  Classification (Multiclass)             Class              None
# 25  Classification (Multiclass)               NSP              None
# 26                   Clustering              None              None
# 27                   Clustering              None              None
# 28                   Clustering              None              None
# 29                   Clustering              None              None
# 30                   Clustering              None              None
# 31                   Clustering              None              None
# 32                   Clustering              None              None
# 33                   Clustering              None              None
# 34                   Clustering              None              None
# 35                   Clustering              None              None
# 36                   Clustering              None              None
# 37                   Clustering              None              None
# 38                   Clustering              None              None
# 39                          NLP             tweet              None
# 40         NLP / Classification        reviewText              None
# 41         NLP / Classification                en              None
# 42             NLP / Regression              text              None
# 43         NLP / Classification              Text              None
# 44                   Regression             price              None
# 45                   Regression               cnt              None
# 46                   Regression              medv              None
# 47                   Regression          strength              None
# 48                   Regression             Price              None
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area              None
# 51                   Regression         Gold_T+22              None
# 52                   Regression         SalePrice              None
# 53                   Regression           charges              None
# 54                   Regression               PPE              None
# 55                   Regression    traffic_volume              None
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %% [markdown]
# ---
# ### **1.2 Get the "blood" dataset**
# ---

# %%
bloodDataSet = get_data("blood")    # SN is 30
# This is unsupervised dataset.
# No target is defined.
# Out:
#    Recency  Frequency  Monetary  Time  Class
# 0        2         50     12500    98      1
# 1        0         13      3250    28      1
# 2        1         16      4000    35      1
# 3        2         20      5000    45      1
# 4        1         24      6000    77      0

# %% [markdown]
# ---
# ### **1.3 Download the "blood" dataset to local system**
# ---

# %%
bloodDataSet.to_csv("bloodDataSet.csv")

#files.download('bloodDataSet.csv')

# %% [markdown]
#   ---
# ### **1.4 "Parameter setting"  for clustering model**
# ##### **Train/Test division, applying data pre-processing** {Sampling, Normalization, Transformation, PCA, Handaling of Outliers, Feature Selection}
# ---

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(bloodDataSet)
# Re-run the code if any error occur
# Out:
# <style type="text/css">
# #T_b7697_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b7697" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7697_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b7697_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7697_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7697_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b7697_row0_col1" class="data row0 col1" >4718</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b7697_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_b7697_row1_col1" class="data row1 col1" >(748, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b7697_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_b7697_row2_col1" class="data row2 col1" >(748, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b7697_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_b7697_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b7697_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_b7697_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b7697_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_b7697_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b7697_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_b7697_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b7697_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_b7697_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b7697_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_b7697_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b7697_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_b7697_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b7697_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_b7697_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b7697_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_b7697_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b7697_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b7697_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_b7697_row12_col1" class="data row12 col1" >745f</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# ### **1.5 Building "KMean" clustering model**
# ---

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4728b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4728b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4728b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4728b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4728b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4728b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4728b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4728b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4728b_row0_col0" class="data row0 col0" >0.6193</td>
#       <td id="T_4728b_row0_col1" class="data row0 col1" >2146.5279</td>
#       <td id="T_4728b_row0_col2" class="data row0 col2" >0.4545</td>
#       <td id="T_4728b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4728b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4728b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **1.6 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
#      Recency  Frequency  Monetary  Time  Class    Cluster
# 0          2         50     12500    98      1  Cluster 3
# 1          0         13      3250    28      1  Cluster 2
# 2          1         16      4000    35      1  Cluster 2
# 3          2         20      5000    45      1  Cluster 2
# 4          1         24      6000    77      0  Cluster 2
# ..       ...        ...       ...   ...    ...        ...
# 743       23          2       500    38      0  Cluster 0
# 744       21          2       500    52      0  Cluster 0
# 745       23          3       750    62      0  Cluster 0
# 746       39          1       250    39      0  Cluster 0
# 747       72          1       250    72      0  Cluster 0
#
# [748 rows x 6 columns]

# %% [markdown]
# ---
# ### **1.7 Clustering in "Three line of code"**
# ---

# %%
from pycaret.clustering import *

kMeanClusteringParameters = setup(bloodDataSet, verbose=False)
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_6d608" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d608_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6d608_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6d608_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6d608_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6d608_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6d608_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d608_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6d608_row0_col0" class="data row0 col0" >0.6298</td>
#       <td id="T_6d608_row0_col1" class="data row0 col1" >2203.1409</td>
#       <td id="T_6d608_row0_col2" class="data row0 col2" >0.4543</td>
#       <td id="T_6d608_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6d608_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6d608_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#      Recency  Frequency  Monetary  Time  Class    Cluster
# 0          2         50     12500    98      1  Cluster 2
# 1          0         13      3250    28      1  Cluster 3
# 2          1         16      4000    35      1  Cluster 3
# 3          2         20      5000    45      1  Cluster 3
# 4          1         24      6000    77      0  Cluster 3
# ..       ...        ...       ...   ...    ...        ...
# 743       23          2       500    38      0  Cluster 0
# 744       21          2       500    52      0  Cluster 0
# 745       23          3       750    62      0  Cluster 0
# 746       39          1       250    39      0  Cluster 0
# 747       72          1       250    72      0  Cluster 0
#
# [748 rows x 6 columns]

# %% [markdown]
# ---
# ### **1.8 "Saving" the result**
# ---

# %%
kMeanPrediction.to_csv("KMeanResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %% [markdown]
# ---
# # **2. Clustering: Saving and Loading the Model**
# ---
# ### **2.1 Save the "trained model"**
# ---

# %%
x = save_model(KMeanClusteringModel, 'kMeanClusteringModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %% [markdown]
# ---
# ### **2.2 Download the "trained model**
# ---

# %%
from google.colab import files
#files.download('kMeanClusteringModelFile.pkl')      # Uncomment this line

# %% [markdown]
# ---
# ### **2.3 Load the model**
# ---
# ##### Use it, while working on **"Anaconda/Jupyter notebook"** on local machine

# %%
KMeanClusteringModel1 = load_model('kMeanClusteringModelFile')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ---
# ### **2.4 Upload and Load the trained model to "Colab Environment"**
# ---
# ##### **Upload the trained model**

# %%
#from google.colab import files
#files.upload()                     # Uncomment this line

# %% [markdown]
# ##### **Load the trained model**

# %%
#KMeanClusteringModel1 = load_model('kMeanClusteringModelFile (1)')

# %% [markdown]
# ---
# # **3. Clustering: Cluster the new dataset (Unseen Data)**
# ---
# ### **3.1 Select some data or upload user dataset file**

# %%
# Select top 10 rows
newData = get_data("blood").iloc[:10]
# Out:
#    Recency  Frequency  Monetary  Time  Class
# 0        2         50     12500    98      1
# 1        0         13      3250    28      1
# 2        1         16      4000    35      1
# 3        2         20      5000    45      1
# 4        1         24      6000    77      0

# %% [markdown]
# ---
# ### **3.2 Make prediction on the new dataset (Unseen Data)**
# ---

# %%
newPredictions = predict_model(KMeanClusteringModel, data = newData)
newPredictions
# Out:
#    Recency  Frequency  Monetary  Time  Class    Cluster
# 0      2.0       50.0   12500.0  98.0    1.0  Cluster 2
# 1      0.0       13.0    3250.0  28.0    1.0  Cluster 3
# 2      1.0       16.0    4000.0  35.0    1.0  Cluster 3
# 3      2.0       20.0    5000.0  45.0    1.0  Cluster 3
# 4      1.0       24.0    6000.0  77.0    0.0  Cluster 3
# 5      4.0        4.0    1000.0   4.0    0.0  Cluster 0
# 6      2.0        7.0    1750.0  14.0    1.0  Cluster 1
# 7      1.0       12.0    3000.0  35.0    0.0  Cluster 1
# 8      2.0        9.0    2250.0  22.0    1.0  Cluster 1
# 9      5.0       46.0   11500.0  98.0    1.0  Cluster 2

# %% [markdown]
# ---
# ### **3.3 Save the prediction result to csv**
# ---

# %%
newPredictions.to_csv("NewPredictions.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

#
[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[4],[2],[2],[2],[11],[4],[4],[4],[4],[4],[4],[4],[4],[4],[4],[4],[11],[6],[2],[6],[2],[2],[2],[4],[4],[4],[2],[10],[4],[2],[2],[4],[4],[11],[4],[4],[4],[4],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[2],[0],[2],[2],[4],[4],[4],[4],[4],[4],[4],[2],[9],[2],[2],[2],[2],[4],[2],[2],[4],[2],[2],[4],[2],[2],[4],[4],[2],[3],[2],[2],[2],[2],[4],[2],[4],[4],[4],[4],[4],[4],[7],[0],[13],[3],[14],[4],[2],[2],[2],[4],[4],[2],[11],[11],[11],[4],[11],[14],[11],[11],[2],[14],[14],[14],[14],[14],[14],[14],[8],[2],[11],[4],[11],[14],[14],[14],[9],[4],[11],[11],[4],[4],[4],[9],[11],[4],[4],[4],[4],[4],[4],[4],[2],[4],[2],[4],[4]],"hovertemplate":"Cluster=Cluster 0\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cbr\u003eFeature=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cluster 0","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"Cluster 0","scene":"scene","showlegend":true,"x":[-6.351752,-14.609249,-8.064496,-17.470907,-13.048937,-2.404143,-6.3768206,-0.38327762,-18.934765,-0.38327762,-13.709488,-20.611109,-20.611109,-6.4191313,-15.941248,-12.328498,-17.548449,-15.8032675,-8.349472,6.088519,-39.22875,1.4283922,-39.22875,-39.22875,-39.22875,-39.22875,-39.22875,-19.126143,-18.559877,-14.611043,-18.559877,-18.559877,0.7772172,-2.2387998,-16.251417,-17.432209,-36.928722,-36.928722,-36.928722,-38.529335,-38.529335,-38.529335,-38.529335,-38.529335,-38.529335,-38.529335,-38.529335,-5.2574725,-10.581771,-14.158743,-2.4977636,-22.668495,-3.1510925,-10.057632,3.809025,-13.599074,1.3503709,-11.6137,-36.928722,-36.928722,-36.928722,-36.928722,-36.928722,-36.928722,-39.199543,-39.22875,-36.928722,3.9865837,-2.2118652,-1.0259936,-43.406826,-24.486797,1.3969225,-15.343398,-36.928722,-3.3671484,-39.22875,-39.22875,-34.66448,-34.66448,-34.66448,-34.66448,-34.66448,-34.66448,-34.66448 ...

# %% [markdown]
# ---
# ### **4.4 Elbow Plot**
# ---

# %%
plot_model(KMeanClusteringModel, plot = 'elbow')

# %% [markdown]
# ---
# ### **4.5 Silhouette Plot**
# ---

# %%
plot_model(KMeanClusteringModel, plot = 'silhouette')

# %% [markdown]
# ---
# ### **4.6 Distribution Plot**
# ---

# %%
plot_model(KMeanClusteringModel, plot = 'distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a2212eaa-c37e-4753-b051-129729e6a65e" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2212eaa-c37e-4753-b051-129729e6a65e")) {                    Plotly.newPlot(                        "a2212eaa-c37e-4753-b051-129729e6a65e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Cluster=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cluster 0","marker":{"color":"#636efa","opacity":0.7,"pattern":{"shape":""}},"name":"Cluster 0","offsetgroup":"Cluster 0","orientation":"v","showlegend":true,"x":["Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cluster 0","Cl ...

# %% [markdown]
# ---
# ### **4.7 Distance Plot**
# ---

# %%
plot_model(KMeanClusteringModel, plot = 'distance') # Rerun the code

# %% [markdown]
# ---
# # **5. Compelete Code for Clustering (KMean)**
# ---
# ### **5.1 For Cluster = 3, 4, 5, 6**

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

bloodDataSet = get_data('blood', verbose=False)
setup(data = bloodDataSet, verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_f685b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f685b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f685b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f685b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f685b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f685b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f685b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f685b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f685b_row0_col0" class="data row0 col0" >0.6284</td>
#       <td id="T_f685b_row0_col1" class="data row0 col1" >1342.6437</td>
#       <td id="T_f685b_row0_col2" class="data row0 col2" >0.5712</td>
#       <td id="T_f685b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f685b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f685b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_9a50f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a50f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9a50f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9a50f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9a50f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9a50f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9a50f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a50f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a50f_row0_col0" class="data row0 col0" >0.6298</td>
#       <td id="T_9a50f_row0_col1" class="data row0 col1" >2203.1409</td>
#       <td id="T_9a50f_row0_col2" class="data row0 col2" >0.4543</td>
#       <td id="T_9a50f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9a50f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9a50f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_08655" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08655_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_08655_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_08655_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_08655_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_08655_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_08655_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08655_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08655_row0_col0" class="data row0 col0" >0.5903</td>
#       <td id="T_08655_row0_col1" class="data row0 col1" >2560.4370</td>
#       <td id="T_08655_row0_col2" class="data row0 col2" >0.4855</td>
#       <td id="T_08655_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_08655_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_08655_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_48344" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48344_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_48344_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_48344_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_48344_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_48344_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_48344_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48344_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48344_row0_col0" class="data row0 col0" >0.5871</td>
#       <td id="T_48344_row0_col1" class="data row0 col1" >3036.8094</td>
#       <td id="T_48344_row0_col2" class="data row0 col2" >0.5238</td>
#       <td id="T_48344_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_48344_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_48344_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **5.2 Other Clustering Algorithms**
# ---
# ```
# - K-Means clustering                 'kmeans'
# - Affinity Propagation               'ap'
# - Mean shift clustering              'meanshift'
# - Spectral Clustering                'sc'
# - Agglomerative Clustering           'hclust'
# - Density-Based Spatial Clustering   'dbscan'
# - OPTICS Clustering                  'optics'
# - Birch Clustering                   'birch'
# - K-Modes clustering                 'kmodes'
# ```

# %% [markdown]
# ---
# # **6. Clustering: Apply "Data Preprocessing"**
# ---
# ### **Read the Dataset**

# %%
from pycaret.clustering import *
from pycaret.datasets import get_data

bloodDataSet = get_data('blood')
# Out:
#    Recency  Frequency  Monetary  Time  Class
# 0        2         50     12500    98      1
# 1        0         13      3250    28      1
# 2        1         16      4000    35      1
# 3        2         20      5000    45      1
# 4        1         24      6000    77      0

# %% [markdown]
# ---
# ### **6.1 Model Performance using "Normalization"**
# ---
# ### **6.1.1 Elbow Plot**

# %%
setup(data = bloodDataSet, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8733" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8733_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b8733_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b8733_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b8733_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b8733_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b8733_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8733_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8733_row0_col0" class="data row0 col0" >0.3317</td>
#       <td id="T_b8733_row0_col1" class="data row0 col1" >336.8443</td>
#       <td id="T_b8733_row0_col2" class="data row0 col2" >1.0602</td>
#       <td id="T_b8733_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b8733_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b8733_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.1.2 Evaluation parameters for Cluster = 3, 4, 5, 6**
# ---

# %%
setup(data = bloodDataSet, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_9719e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9719e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9719e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9719e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9719e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9719e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9719e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9719e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9719e_row0_col0" class="data row0 col0" >0.3906</td>
#       <td id="T_9719e_row0_col1" class="data row0 col1" >336.5596</td>
#       <td id="T_9719e_row0_col2" class="data row0 col2" >0.9712</td>
#       <td id="T_9719e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9719e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9719e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_50942" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50942_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_50942_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_50942_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_50942_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_50942_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_50942_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50942_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50942_row0_col0" class="data row0 col0" >0.3878</td>
#       <td id="T_50942_row0_col1" class="data row0 col1" >352.1389</td>
#       <td id="T_50942_row0_col2" class="data row0 col2" >1.0153</td>
#       <td id="T_50942_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_50942_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_50942_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_8916f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8916f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8916f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8916f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8916f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8916f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8916f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8916f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8916f_row0_col0" class="data row0 col0" >0.3443</td>
#       <td id="T_8916f_row0_col1" class="data row0 col1" >352.9601</td>
#       <td id="T_8916f_row0_col2" class="data row0 col2" >1.0126</td>
#       <td id="T_8916f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8916f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8916f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_b1bd8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b
_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fd11b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fd11b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_32100" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32100_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_32100_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_32100_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_32100_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_32100_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_32100_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32100_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32100_row0_col0" class="data row0 col0" >0.3648</td>
#       <td id="T_32100_row0_col1" class="data row0 col1" >410.4612</td>
#       <td id="T_32100_row0_col2" class="data row0 col2" >0.9746</td>
#       <td id="T_32100_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_32100_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_32100_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_842e6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_842e6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_842e6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_842e6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_842e6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_842e6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_842e6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_842e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_842e6_row0_col0" class="data row0 col0" >0.3235</td>
#       <td id="T_842e6_row0_col1" class="data row0 col1" >397.6360</td>
#       <td id="T_842e6_row0_col2" class="data row0 col2" >1.0953</td>
#       <td id="T_842e6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_842e6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_842e6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.5 Model Performance using "Transformation" + "Normalization" + "PCA"**
# ---
# ### **6.5.1 Elbow Plot**

# %%
setup(data = bloodDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_04c8a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04c8a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_04c8a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_04c8a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_04c8a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_04c8a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_04c8a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04c8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04c8a_row0_col0" class="data row0 col0" >0.3627</td>
#       <td id="T_04c8a_row0_col1" class="data row0 col1" >444.1037</td>
#       <td id="T_04c8a_row0_col2" class="data row0 col2" >1.0558</td>
#       <td id="T_04c8a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_04c8a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_04c8a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **6.5.2 Evaluation parameters for Cluster = 3, 4, 5, 6**
# ---

# %%
setup(data = bloodDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_21c48" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21c48_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_21c48_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_21c48_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_21c48_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_21c48_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_21c48_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21c48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21c48_row0_col0" class="data row0 col0" >0.3606</td>
#       <td id="T_21c48_row0_col1" class="data row0 col1" >438.8009</td>
#       <td id="T_21c48_row0_col2" class="data row0 col2" >1.0587</td>
#       <td id="T_21c48_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_21c48_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_21c48_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_f538a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f538a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f538a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f538a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f538a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f538a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f538a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f538a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f538a_row0_col0" class="data row0 col0" >0.3061</td>
#       <td id="T_f538a_row0_col1" class="data row0 col1" >397.4814</td>
#       <td id="T_f538a_row0_col2" class="data row0 col2" >1.1086</td>
#       <td id="T_f538a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f538a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f538a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_8341f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8341f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8341f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8341f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8341f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8341f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8341f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8341f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8341f_row0_col0" class="data row0 col0" >0.3228</td>
#       <td id="T_8341f_row0_col1" class="data row0 col1" >381.1612</td>
#       <td id="T_8341f_row0_col2" class="data row0 col2" >1.0927</td>
#       <td id="T_8341f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8341f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8341f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_d9536" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9536_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d9536_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d9536_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d9536_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d9536_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d9536_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9536_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9536_row0_col0" class="data row0 col0" >0.3211</td>
#       <td id="T_d9536_row0_col1" class="data row0 col1" >328.9316</td>
#       <td id="T_d9536_row0_col2" class="data row0 col2" >1.0611</td>
#       <td id="T_d9536_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d9536_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d9536_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# # **7. Other Clustering Techniques**
# ---
# ```
# K-Means clustering                 'kmeans'
# Affinity Propagation               'ap'
# Mean shift clustering              'meanshift'
# Spectral Clustering                'sc'
# Agglomerative Clustering           'hclust'
# Density-Based Spatial Clustering   'dbscan'
# OPTICS Clustering                  'optics'
# Birch Clustering                   'birch'
# K-Modes clustering                 'kmodes'
# ```

# %% [markdown]
# ---
# ### **7.1 Buildign Agglomerative (Hierarchical) clustering model**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

bloodDataSet = get_data('blood', verbose=False)
setup(data = bloodDataSet, verbose=False)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac3dc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac3dc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ac3dc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ac3dc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ac3dc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ac3dc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ac3dc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac3dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac3dc_row0_col0" class="data row0 col0" >0.6193</td>
#       <td id="T_ac3dc_row0_col1" class="data row0 col1" >2146.5279</td>
#       <td id="T_ac3dc_row0_col2" class="data row0 col2" >0.4545</td>
#       <td id="T_ac3dc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ac3dc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ac3dc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **7.1.1 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
hierarchicalModel = create_model('hclust', num_clusters=3)
hierarchicalModelPrediction = assign_model(hierarchicalModel)
hierarchicalModelPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_f75b3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f75b3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f75b3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f75b3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f75b3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f75b3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f75b3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f75b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f75b3_row0_col0" class="data row0 col0" >0.6857</td>
#       <td id="T_f75b3_row0_col1" class="data row0 col1" >1408.0363</td>
#       <td id="T_f75b3_row0_col2" class="data row0 col2" >0.4078</td>
#       <td id="T_f75b3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f75b3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f75b3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#      Recency  Frequency  Monetary  Time  Class    Cluster
# 0          2         50     12500    98      1  Cluster 2
# 1          0         13      3250    28      1  Cluster 1
# 2          1         16      4000    35      1  Cluster 1
# 3          2         20      5000    45      1  Cluster 1
# 4          1         24      6000    77      0  Cluster 1
# ..       ...        ...       ...   ...    ...        ...
# 743       23          2       500    38      0  Cluster 0
# 744       21          2       500    52      0  Cluster 0
# 745       23          3       750    62      0  Cluster 0
# 746       39          1       250    39      0  Cluster 0
# 747       72          1       250    72      0  Cluster 0
#
# [748 rows x 6 columns]

# %% [markdown]
# ---
# ### **7.1.2 Evaluate Agglomerative (Hierarchical) Clustering**
# ---

# %%
evaluate_model(hierarchicalModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ---
# ### **7.2 Density-Based Spatial Clustering**
# ---

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

bloodDataSet = get_data('blood', verbose=False)
setup(data = bloodDataSet, verbose=False)
dbscanModel = create_model('dbscan')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e4ba0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4ba0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e4ba0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e4ba0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e4ba0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e4ba0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e4ba0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4ba0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4ba0_row0_col0" class="data row0 col0" >-0.1904</td>
#       <td id="T_e4ba0_row0_col1" class="data row0 col1" >11.2149</td>
#       <td id="T_e4ba0_row0_col2" class="data row0 col2" >0.8398</td>
#       <td id="T_e4ba0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e4ba0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e4ba0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ---
# ### **7.2.1 Assign Model - "Assign the labels" to the dataset**
# ---

# %%
dbscanModelPrediction = assign_model(dbscanModel)
dbscanModelPrediction

# Noisy samples are given the label -1 i.e. 'Cluster -1'
# Out:
#      Recency  Frequency  Monetary  Time  Class     Cluster
# 0          2         50     12500    98      1  Cluster -1
# 1          0         13      3250    28      1  Cluster -1
# 2          1         16      4000    35      1  Cluster -1
# 3          2         20      5000    45      1  Cluster -1
# 4          1         24      6000    77      0  Cluster -1
# ..       ...        ...       ...   ...    ...         ...
# 743       23          2       500    38      0  Cluster -1
# 744       21          2       500    52      0  Cluster -1
# 745       23          3       750    62      0  Cluster -1
# 746       39          1       250    39      0  Cluster -1
# 747       72          1       250    72      0  Cluster -1
#
# [748 rows x 6 columns]

# %% [markdown]
# ### **Key Points**

# %% [markdown]
# - num_clusters not required for some of the clustering Alorithms (Affinity Propagation ('ap'), Mean shift
#   clustering ('meanshift'), Density-Based Spatial Clustering ('dbscan') and OPTICS Clustering ('optics')).
# - num_clusters param for these models are automatically determined.
#
# - When fit doesn't converge in Affinity Propagation ('ap') model, all datapoints are labelled as -1.
#
# - Noisy samples are given the label -1, when using Density-Based Spatial  ('dbscan') or OPTICS Clustering ('optics').
#
# - OPTICS ('optics') clustering may take longer training times on large datasets.
